# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## Video segmentation and tracking with SAM 3
#
# This notebook demonstrates how to use SAM 3 for interactive video segmentation and dense tracking. It covers the following capabilities:
#
# - **Text prompts**: Using natural language descriptions to segment objects (e.g., "person", "shoe")
# - **Point prompts**: Adding positive/negative clicks to segment and refine objects
#
# We use the terms _segment_ or _mask_ to refer to the model prediction for an object on a single frame, and _masklet_ to refer to the spatio-temporal masks across the entire video.

# %% [markdown]
# # <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/sam3/blob/main/notebooks/sam3_video_predictor_example.ipynb">
# #   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# # </a>

# %%
using_colab = False

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib scikit-learn
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/sam3.git'

# %%
# !nvidia-smi
# Out:
# Mon Apr 27 22:36:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...    On  |   00000000:01:00.0  On |                  N/A |
# | N/A   48C    P3              9W /   55W |     104MiB /   8188MiB |     12%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1970      G   /usr/lib/xorg/Xorg                       83MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Set-up
#
# In this example, we allow running inference either on a single GPU or multiple GPUs.

# %%
import os
import sam3
import torch

sam3_root = os.path.join(os.path.dirname(sam3.__file__), "..")

# use all available GPUs on the machine
gpus_to_use = range(torch.cuda.device_count())
# # use only a single GPU
# gpus_to_use = [torch.cuda.current_device()]
# Out:
# /home/wlsoo/miniconda3/envs/sam3/lib/python3.12/site-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
from sam3.model_builder import build_sam3_video_predictor

predictor = build_sam3_video_predictor(gpus_to_use=gpus_to_use)
# Out:
# INFO 2026-04-27 22:36:46,233 346295 sam3_video_predictor.py: 109: using the following GPU IDs: [0]
# INFO 2026-04-27 22:36:46,364 346295 sam3_video_predictor.py: 125:
#
#
# 	*** START loading model on all ranks ***
#
#
# INFO 2026-04-27 22:36:46,364 346295 sam3_video_predictor.py: 127: loading model on rank=0 with world_size=1 -- this could take a while ...
# INFO 2026-04-27 22:36:50,474 346295 sam3_video_base.py: 348: setting max_num_objects=10000 and num_obj_for_compile=16
# INFO 2026-04-27 22:36:54,689 346295 sam3_video_predictor.py: 129: loading model on rank=0 with world_size=1 -- DONE locally
# INFO 2026-04-27 22:36:54,697 346295 sam3_video_predictor.py: 140:
#
#
# 	*** DONE loading model on all ranks ***

# %% [markdown]
# #### Inference and visualization utils

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sam3.visualization_utils import (
    load_frame,
    prepare_masks_for_visualization,
    visualize_formatted_frame_output,
)

# font size for axes titles
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["figure.titlesize"] = 12


def propagate_in_video(predictor, session_id):
    # we will just propagate from frame 0 to the end of the video
    outputs_per_frame = {}
    for response in predictor.handle_stream_request(
        request=dict(
            type="propagate_in_video",
            session_id=session_id,
        )
    ):
        outputs_per_frame[response["frame_index"]] = response["outputs"]

    return outputs_per_frame


def abs_to_rel_coords(coords, IMG_WIDTH, IMG_HEIGHT, coord_type="point"):
    """Convert absolute coordinates to relative coordinates (0-1 range)

    Args:
        coords: List of coordinates
        coord_type: 'point' for [x, y] or 'box' for [x, y, w, h]
    """
    if coord_type == "point":
        return [[x / IMG_WIDTH, y / IMG_HEIGHT] for x, y in coords]
    elif coord_type == "box":
        return [
            [x / IMG_WIDTH, y / IMG_HEIGHT, w / IMG_WIDTH, h / IMG_HEIGHT]
            for x, y, w, h in coords
        ]
    else:
        raise ValueError(f"Unknown coord_type: {coord_type}")

# %% [markdown]
# ### Loading an example video
#
# We assume that the video is stored as either **a list of JPEG frames with filenames like `<frame_index>.jpg`** or **an MP4 video**.
#
# Note that you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# "video_path" needs to be either a JPEG folder or a MP4 video file
video_path = f"{sam3_root}/assets/videos/0001"

# %%
# load "video_frames_for_vis" for visualization purposes (they are not used by the model)
if isinstance(video_path, str) and video_path.endswith(".mp4"):
    cap = cv2.VideoCapture(video_path)
    video_frames_for_vis = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        video_frames_for_vis.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
else:
    video_frames_for_vis = glob.glob(os.path.join(video_path, "*.jpg"))
    try:
        # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")
        video_frames_for_vis.sort(
            key=lambda p: int(os.path.splitext(os.path.basename(p))[0])
        )
    except ValueError:
        # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
        print(
            f'frame names are not in "<frame_index>.jpg" format: {video_frames_for_vis[:5]=}, '
            f"falling back to lexicographic sort."
        )
        video_frames_for_vis.sort()

# %% [markdown]
# ### Opening an inference session on this video
#
# SAM 3 requires stateful inference for interactive video segmentation, so we need to initialize an **inference session** on this video.
#
# During initialization, it loads all the video frames and stores their pixels in the session state.

# %%
response = predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_path,
    )
)
session_id = response["session_id"]
# Out:
# frame loading (image folder) [rank=0]: 100%|██████████| 270/270 [00:03<00:00, 73.61it/s]
# INFO 2026-04-27 22:37:01,357 346295 sam3_base_predictor.py: 134: started new session 1439b120-4be9-431f-83f1-8cde6a02dc4f

# %% [markdown]
# ### Video promptable concept segmentation with text
#
# Using SAM 3 you can describe objects using natural language, and the model will automatically detect and track all instances of that object throughout the video.
#
# In the example below, we add a text prompt on frame 0 and propagation throughout the video. Here we use the text prompt "person" to detect all people in the video. SAM 3 will automatically identify multiple person instances and assign each a unique object ID.
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
_ = predictor.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)

# %%
prompt_text_str = "person"
frame_idx = 0  # add a text prompt on frame 0
response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )
# Out:
# propagate_in_video:   0%|          | 0/270 [00:00<?, ?it/s]
# INFO 2026-04-27 22:37:09,306 346295 sam3_base_predictor.py: 293: propagation ended in session 1439b120-4be9-431f-83f1-8cde6a02dc4f
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[13], line 2
#       1 # now we propagate the outputs from frame 0 to the end of the video and collect all outputs
# ----> 2 outputs_per_frame = propagate_in_video(predictor, session_id)
#       3
#       4 # finally, we reformat the outputs for visualization and plot the outputs every 60 frames
#       5 outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)
#
# Cell In[7], line 22, in propagate_in_video(predictor, session_id)
#      19 def propagate_in_video(predictor, session_id):
#      20     # we will just propagate from frame 0 to the end of the video
#      21     outputs_per_frame = {}
# ---> 22     for response in predictor.handle_stream_request(
#      23         request=dict(
#      24             type="propagate_in_video",
#      25             session_id=session_id,
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~/github/sam3/sam3/model/sam3_video_predictor.py:178, in Sam3VideoPredictorMultiGPU.handle_stream_request(self, request)
#     175     for rank in range(1, self.world_size):
#     176         self.command_queues[rank].put((request, True))
# --> 178 yield from super().handle_stream_request(request)
#     180 if self.world_size > 1:
#     181     torch.distributed.barrier()
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~/github/sam3/sam3/model/sam3_base_predictor.py:92, in Sam3BasePredictor.handle_stream_request(self, request)
#      90 request_type = request["type"]
#      91 if request_type == "propagate_in_video":
# ---> 92     yield from self.propagate_in_video(
#      93         session_id=request["session_id"],
#      94         propagation_direction=request.get("propagation_direction", "both"),
#      95         start_frame_idx=request.get("start_frame_index", None),
#      96         max_frame_num_to_track=request.get("max_frame_num_to_track", None),
#      97         output_prob_thresh=request.get(
#      98             "output_prob_thresh",
#      99             getattr(self, "default_output_prob_thresh", 0.5),
#     100         ),
#     101     )
#     102 else:
#     103     raise RuntimeError(f"invalid request type: {request_type}")
#
# File ~/github/sam3/sam3/model/sam3_base_predictor.py:280, in Sam3BasePredictor.propagate_in_video(self, session_id, propagation_direction, start_frame_idx, max_frame_num_to_track, output_prob_thresh, **kwargs)
#     278 # Forward propagation
#     279 if propagation_direction in ["both", "forward"]:
# --> 280     for frame_idx, outputs in self.model.propagate_in_video(
#     281         **propagate_kwargs,
#     282         reverse=False,
#     283     ):
#     284         yield {"frame_index": frame_idx, "outputs": outputs}
#     285 # Backward propagation
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~/github/sam3/sam3/model/sam3_video_inference.py:1017, in Sam3VideoInferenceWithInstanceInteractivity.propagate_in_video(self, inference_state, start_frame_idx, max_frame_num_to_track, reverse)
#    1015 if propagation_type == "propagation_full":
#    1016     logger.debug(f"Running full VG propagation (reverse={reverse}).")
# -> 1017     yield from super().propagate_in_video(
#    1018         inference_state,
#    1019         start_frame_idx=start_frame_idx,
#    1020         max_frame_num_to_track=max_frame_num_to_track,
#    1021         reverse=reverse,
#    1022     )
#    1023     return
#    1025 # step 3: run Tracker partial propagation or direct fetch existing predictions
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~/github/sam3/sam3/model/sam3_video_inference.py:295, in Sam3VideoInference.propagate_in_video(self, inference_state, start_frame_idx, max_frame_num_to_track, reverse)
#     291 unconfirmed_obj_ids_per_frame = {}  # frame_idx -> hidden_obj_ids
#     292 for frame_idx in tqdm(
#     293     processing_order, desc="propagate_in_video", disable=self.rank > 0
#     294 ):
# --> 295     out = self._run_single_frame_inference(inference_state, frame_idx, reverse)
#     297     if self.hotstart_delay > 0:
#     298         # accumulate the outputs for the first `hotstart_delay` frames
#     299         hotstart_buffer.append([frame_idx, out])
#
# File ~/github/sam3/sam3/model/sam3_video_inference.py:380, in Sam3VideoInference._run_single_frame_inference(self, inference_state, frame_idx, reverse)
#     369 has_geometric_prompt = (
#     370     inference_state["per_frame_geometric_prompt"][frame_idx] is not None
#     371 )
#     372 # run inference for the current frame
#     373 (
#     374     obj_id_to_mask,
#     375     obj_id_to_score,
#     376     tracker_states_local_new,
#     377     tracker_metadata_new,
#     378     frame_stats,
#     379     _,
# --> 380 ) = self._det_track_one_frame(
#     381     frame_idx=frame_idx,
#     382     num_frames=inference_state["num_frames"],
#     383     reverse=reverse,
#     384     input_batch=input_batch,
#     385     geometric_prompt=(
#     386         inference_state["constants"]["empty_geometric_prompt"]
#     387         if not has_geometric_prompt
#     388         else inference_state["per_frame_geometric_prompt"][frame_idx]
#     389     ),
#     390     tracker_states_local=tracker_states_local,
#     391     tracker_metadata_prev=inference_state["tracker_metadata"],
#     392     feature_cache=inference_state["feature_cache"],
#     393     orig_vid_height=inference_state["orig_height"],
#     394     orig_vid_width=inference_state["orig_width"],
#     395     is_image_only=inference_state["is_image_only"],
#     396     allow_new_detections=has_text_prompt or has_geometric_prompt,
#     397 )
#     398 # update inference state
#     399 inference_state["tracker_inference_states"] = tracker_states_local_new
#
# File ~/github/sam3/sam3/model/sam3_video_base.py:426, in Sam3VideoBase._det_track_one_frame(self, frame_idx, num_frames, reverse, input_batch, geometric_prompt, tracker_states_local, tracker_metadata_prev, feature_cache, orig_vid_height, orig_vid_width, is_image_only, allow_new_detections)
#     422 if tracker_metadata_prev == {}:
#     423     # initialize masklet metadata if it's uninitialized (empty dict)
#     424     tracker_metadata_prev.update(self._initialize_metadata())
#     425 tracker_low_res_masks_global, tracker_obj_scores_global = (
# --> 426     self.run_tracker_propagation(
#     427         frame_idx=frame_idx,
#     428         num_frames=num_frames,
#     429         reverse=reverse,
#     430         tracker_states_local=tracker_states_local,
#     431         tracker_metadata_prev=tracker_metadata_prev,
#     432     )
#     433 )
#     435 # Step 3: based on detection outputs and the propagated SAM2 prediction masks, we make plans
#     436 # for SAM2 masklet updates (i.e. which objects to add and remove, how to load-balance them, etc).
#     437 # We also run SAM2 memory encoder globally in this step to resolve non-overlapping constraints.
#    (...)    440 # broadcasted to other GPUs (to be executed in a distributed manner). This step also generates the
#     441 # new masklet metadata `tracker_metadata_new` (based on its previous version `tracker_metadata_prev`).
#     442 tracker_update_plan, tracker_metadata_new = (
#     443     self.run_tracker_update_planning_phase(
#     444         frame_idx=frame_idx,
#    (...)    453     )
#     454 )
#
# File ~/github/sam3/sam3/model/sam3_video_base.py:638, in Sam3VideoBase.run_tracker_propagation(self, frame_idx, num_frames, reverse, tracker_states_local, tracker_metadata_prev)
#     625 def run_tracker_propagation(
#     626     self,
#     627     frame_idx: int,
#    (...)    635     # - obj_ids_local: List[int] -- list of object IDs
#     636     # - low_res_masks_local: Tensor -- (num_local_obj, H_mask, W_mask)
#     637     obj_ids_local, low_res_masks_local, obj_scores_local = (
# --> 638         self._propogate_tracker_one_frame_local_gpu(
#     639             tracker_states_local, frame_idx=frame_idx, reverse=reverse
#     640         )
#     641     )
#     643     assert np.all(
#     644         obj_ids_local == tracker_metadata_prev["obj_ids_per_gpu"][self.rank]
#     645     ), "{} != {}".format(
#     646         obj_ids_local, tracker_metadata_prev["obj_ids_per_gpu"][self.rank]
#     647     )
#     649     # Step 2: all-gather `low_res_masks_local` into `low_res_masks_global`
#     650     # - low_res_masks_global: Tensor -- (num_global_obj, H_mask, W_mask)
#
# File ~/github/sam3/sam3/model/sam3_video_base.py:1355, in Sam3VideoBase._propogate_tracker_one_frame_local_gpu(self, inference_states, frame_idx, reverse, run_mem_encoder)
#    1353 # propagate one frame
#    1354 num_frames_propagated = 0
# -> 1355 for out in self.tracker.propagate_in_video(
#    1356     inference_state,
#    1357     start_frame_idx=frame_idx,
#    1358     # end_frame_idx = start_frame_idx + max_frame_num_to_track
#    1359     # (i.e. propagating 1 frame since end_frame_idx is inclusive)
#    1360     max_frame_num_to_track=0,
#    1361     reverse=reverse,
#    1362     tqdm_disable=True,
#    1363     run_mem_encoder=run_mem_encoder,
#    1364 ):
#    1365     out_frame_idx, out_obj_ids, out_low_res_masks, _, out_obj_scores = out
#    1366     num_frames_propagated += 1
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/utils/_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~/github/sam3/sam3/model/sam3_tracking_predictor.py:848, in Sam3TrackerPredictor.propagate_in_video(self, inference_state, start_frame_idx, max_frame_num_to_track, reverse, tqdm_disable, obj_ids, run_mem_encoder, propagate_preflight)
#     846 else:
#     847     storage_key = "non_cond_frame_outputs"
# --> 848     current_out, pred_masks = self._run_single_frame_inference(
#     849         inference_state=inference_state,
#     850         output_dict=output_dict,
#     851         frame_idx=frame_idx,
#     852         batch_size=batch_size,
#     853         is_init_cond_frame=False,
#     854         point_inputs=None,
#     855         mask_inputs=None,
#     856         reverse=reverse,
#     857         run_mem_encoder=run_mem_encoder,
#     858     )
#     859     obj_scores = current_out["object_score_logits"]
#     860     output_dict[storage_key][frame_idx] = current_out
#
# File ~/github/sam3/sam3/model/sam3_tracking_predictor.py:1076, in Sam3TrackerPredictor._run_single_frame_inference(self, inference_state, output_dict, frame_idx, batch_size, is_init_cond_frame, point_inputs, mask_inputs, reverse, run_mem_encoder, prev_sam_mask_logits, use_prev_mem_frame)
#    1074 # point and mask should not appear as input simultaneously on the same frame
#    1075 assert point_inputs is None or mask_inputs is None
# -> 1076 current_out = self.track_step(
#    1077     frame_idx=frame_idx,
#    1078     is_init_cond_frame=is_init_cond_frame,
#    1079     current_vision_feats=current_vision_feats,
#    1080     current_vision_pos_embeds=current_vision_pos_embeds,
#    1081     feat_sizes=feat_sizes,
#    1082     image=image,
#    1083     point_inputs=point_inputs,
#    1084     mask_inputs=mask_inputs,
#    1085     output_dict=output_dict,
#    1086     num_frames=inference_state["num_frames"],
#    1087     track_in_reverse=reverse,
#    1088     run_mem_encoder=run_mem_encoder,
#    1089     prev_sam_mask_logits=prev_sam_mask_logits,
#    1090     use_prev_mem_frame=use_prev_mem_frame,
#    1091 )
#    1093 # optionally offload the output to CPU memory to save GPU space
#    1094 storage_device = inference_state["storage_device"]
#
# File ~/github/sam3/sam3/model/sam3_tracker_base.py:970, in Sam3TrackerBase.track_step(self, frame_idx, is_init_cond_frame, current_vision_feats, current_vision_pos_embeds, feat_sizes, image, point_inputs, mask_inputs, output_dict, num_frames, track_in_reverse, run_mem_encoder, prev_sam_mask_logits, use_prev_mem_frame)
#     965     sam_outputs = self._use_mask_as_output(
#     966         pix_feat, high_res_features, mask_inputs
#     967     )
#     968 else:
#     969     # fused the visual feature with previous memory features in the memory bank
# --> 970     pix_feat_with_mem = self._prepare_memory_conditioned_features(
#     971         frame_idx=frame_idx,
#     972         is_init_cond_frame=is_init_cond_frame,
#     973         current_vision_feats=current_vision_feats[-1:],
#     974         current_vision_pos_embeds=current_vision_pos_embeds[-1:],
#     975         feat_sizes=feat_sizes[-1:],
#     976         output_dict=output_dict,
#     977         num_frames=num_frames,
#     978         track_in_reverse=track_in_reverse,
#     979         use_prev_mem_frame=use_prev_mem_frame,
#     980     )
#     981     # apply SAM-style segmentation head
#     982     # here we might feed previously predicted low-res SAM mask logits into the SAM mask decoder,
#     983     # e.g. in demo where such logits come from earlier interaction instead of correction sampling
#     984     # (in this case, the SAM mask decoder should have `self.iter_use_prev_mask_pred=True`, and
#     985     # any `mask_inputs` shouldn't reach here as they are sent to _use_mask_as_output instead)
#     986     if prev_sam_mask_logits is not None:
#
# File ~/github/sam3/sam3/model/sam3_tracker_base.py:782, in Sam3TrackerBase._prepare_memory_conditioned_features(self, frame_idx, is_init_cond_frame, current_vision_feats, current_vision_pos_embeds, feat_sizes, output_dict, num_frames, track_in_reverse, use_prev_mem_frame)
#     780 prompt_mask = None  # For now, we always masks are zeros anyways
#     781 prompt_pos_embed = torch.cat(to_cat_prompt_pos_embed, dim=0)
# --> 782 encoder_out = self.transformer.encoder(
#     783     src=current_vision_feats,
#     784     src_key_padding_mask=[None],
#     785     src_pos=current_vision_pos_embeds,
#     786     prompt=prompt,
#     787     prompt_pos=prompt_pos_embed,
#     788     prompt_key_padding_mask=prompt_mask,
#     789     feat_sizes=feat_sizes,
#     790     num_obj_ptr_tokens=num_obj_ptr_tokens,
#     791 )
#     792 # reshape the output (HW)BC => BCHW
#     793 pix_feat_with_mem = encoder_out["memory"].permute(1, 2, 0).view(B, C, H, W)
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/github/sam3/sam3/model/decoder.py:700, in TransformerEncoderCrossAttention.forward(self, src, prompt, src_mask, prompt_mask, src_key_padding_mask, prompt_key_padding_mask, src_pos, prompt_pos, feat_sizes, num_obj_ptr_tokens)
#     697     if isinstance(layer.cross_attn_image, RoPEAttention):
#     698         kwds = {"num_k_exclude_rope": num_obj_ptr_tokens}
# --> 700     output = activation_ckpt_wrapper(layer)(
#     701         tgt=output,
#     702         memory=prompt,
#     703         tgt_mask=src_mask,
#     704         memory_mask=prompt_mask,
#     705         tgt_key_padding_mask=src_key_padding_mask,
#     706         memory_key_padding_mask=prompt_key_padding_mask,
#     707         pos=prompt_pos,
#     708         query_pos=src_pos,
#     709         dac=False,
#     710         attn_bias=None,
#     711         act_ckpt_enable=self.training and self.use_act_checkpoint,
#     712         **kwds,
#     713     )
#     714     normed_output = self.norm(output)
#     716 if self.batch_first:
#     717     # Convert back to seq first
#
# File ~/github/sam3/sam3/model/act_ckpt_utils.py:88, in activation_ckpt_wrapper.<locals>.act_ckpt_wrapper(act_ckpt_enable, use_reentrant, *args, **kwargs)
#      84     ret = checkpoint.checkpoint(
#      85         module, *args, use_reentrant=use_reentrant, **kwargs
#      86     )
#      87 else:
# ---> 88     ret = module(*args, **kwargs)
#      90 return ret
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/github/sam3/sam3/model/decoder.py:957, in TransformerDecoderLayerv2.forward(self, *args, **kwds)
#     955 def forward(self, *args: Any, **kwds: Any) -> torch.Tensor:
#     956     if self.pre_norm:
# --> 957         return self.forward_pre(*args, **kwds)
#     958     raise NotImplementedError
#
# File ~/github/sam3/sam3/model/decoder.py:947, in TransformerDecoderLayerv2.forward_pre(self, tgt, memory, dac, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask, pos, query_pos, attn_bias, num_k_exclude_rope)
#     945 else:
#     946     tgt = self._forward_sa(tgt, query_pos)
# --> 947     tgt = self._forward_ca(tgt, memory, query_pos, pos, num_k_exclude_rope)
#     949 # MLP
#     950 tgt2 = self.norm3(tgt)
#
# File ~/github/sam3/sam3/model/decoder.py:912, in TransformerDecoderLayerv2._forward_ca(self, tgt, memory, query_pos, pos, num_k_exclude_rope)
#     910 # Cross-Attention
#     911 tgt2 = self.norm2(tgt)
# --> 912 tgt2 = self.cross_attn_image(
#     913     q=tgt2 + query_pos if self.pos_enc_at_cross_attn_queries else tgt2,
#     914     k=memory + pos if self.pos_enc_at_cross_attn_keys else memory,
#     915     v=memory,
#     916     **kwds,
#     917 )
#     918 tgt = tgt + self.dropout2(tgt2)
#     919 return tgt
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/sam3/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/github/sam3/sam3/sam/transformer.py:327, in RoPEAttention.forward(self, q, k, v, num_k_exclude_rope)
#     319     q, k[:, :, :num_k_rope] = apply_rotary_enc_real(
#     320         q,
#     321         k[:, :, :num_k_rope],
#    (...)    324         repeat_freqs_k=self.rope_k_repeat,
#     325     )
#     326 else:
# --> 327     q, k[:, :, :num_k_rope] = apply_rotary_enc(
#     328         q,
#     329         k[:, :, :num_k_rope],
#     330         self.freqs_cis,
#     331         repeat_freqs_k=self.rope_k_repeat,
#     332     )
#     334 dropout_p = self.dropout_p if self.training else 0.0
#     335 # Attention
#     336 # with torch.backends.cuda.sdp_kernel(
#     337 #     enable_flash=USE_FLASH_ATTN,
#    (...)    341 # ):
#     342 # Let's trust the dispatcher....
#
# File ~/github/sam3/sam3/sam/rope.py:80, in apply_rotary_enc(xq, xk, freqs_cis, repeat_freqs_k)
#      78     freqs_cis = freqs_cis.repeat(*([1] * (freqs_cis.ndim - 2)), r, 1)
#      79 xk_out = torch.view_as_real(xk_ * freqs_cis).flatten(3)
# ---> 80 return xq_out.type_as(xq).to(xq.device), xk_out.type_as(xk).to(xk.device)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 52.00 MiB. GPU 0 has a total capacity of 7.62 GiB of which 26.12 MiB is free. Including non-PyTorch memory, this process has 7.49 GiB memory in use. Of the allocated memory 7.11 GiB is allocated by PyTorch, and 213.12 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ###  Removing objects
#
# We can remove individual objects using their id.
#
# As an example, let's remove object 2 (which is the dancer in the front).

# %%
# we pick id 2, which is the dancer in the front
obj_id = 2
response = predictor.handle_request(
    request=dict(
        type="remove_object",
        session_id=session_id,
        obj_id=obj_id,
    )
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Adding new objects with point prompts
#
# We can add new objects through point prompts.
#
# Assuming that we've changed our mind, and now that we want to add back the dancer in the front (whom we just removed in the step above). We can use interactive clicks to add her back.

# %%
sample_img = Image.fromarray(load_frame(video_frames_for_vis[0]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %%
# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Refining an existing object with point prompts
#
# We can also refine the segmentation mask of an existing object through point prompts.
#
# Assuming that we've changed our mind (again) -- for Object ID 2 (the dancer in the front whom we just added back in the step above), now we only want to segment her T-shirt instead of her whole body. We can adjust the segmentation mask with a few more positive and negative clicks.

# %%
# For the dancer in the front, suppose now we only want to segment her T-shirt instead of her whole body
# we will use 2 positive clicks and 2 negative clicks to select her shirt.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [740, 450],  # positive click
        [760, 630],  # negative click
        [840, 640],  # negative click
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1, 0, 0, 1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float32,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Close session
#
# Each session is tied to a single video. We can close the session after inference to free up its resources.
#
# (Then, you may start a new session on another video.)

# %%
# finally, close the inference session to free its GPU resources
# (you may start a new session on another video)
_ = predictor.handle_request(
    request=dict(
        type="close_session",
        session_id=session_id,
    )
)

# %% [markdown]
# ### Clean-up
#
# After all inference is done, we can shutdown the predictor to free up the multi-GPU process group.

# %%
# after all inference is done, we can shutdown the predictor
# to free up the multi-GPU process group
predictor.shutdown()
